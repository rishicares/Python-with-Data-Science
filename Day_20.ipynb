# %%
import openpyxl
import pandas as pd
import numpy as np

# %% [raw]
# Types of supervised machine learning
# a)Regression
# b)Classification
# Steps for machine learning:
# -problem identification
# -data collection
#     -manually
#     - web scraping or downloading
#     -buy
# -Data preprocessing
#     -Data cleaning: handling missing values, type conversion, hyperparameter(), model parameter()
# -Encoding(label encoding, one hot encoding)
# -scaling(MinMaxScaler)
# -splitting(80%20%)
# -train model
# -error calculation(mes<, r2>)
# -deployment(heraku, aws)
#     -streamlit(), flask()

# %%
df=pd.read_csv(r"pandas/used_cars_data.csv")

# %% [raw]
# isna(), isnull(), notna(), notnull()

# %%
df_row=df.copy()
df_row1=df.copy()
df_col=df.copy()
df_col1=df.copy()

# %%
df1=df.copy()
df2=df.copy()
df2=df.copy()

# %%
df1.dropna(axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
df2.dropna(how='all')
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
remove=['Mileage','Engine','Power','Seats']

# %%
df2.dropna(subset=remove, inplace=True)
df2
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
df2.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            6193
# Price                1223
# dtype: int64

# %%
df2
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
del_col=['S.No.', 'Location', 'Owner_Type', 'New_Price','Price']

# %%
df2.drop(del_col,axis=1, inplace=True)

# %%
df2
# Out:
#                                                    Name  Year  \
# 0                                Maruti Wagon R LXI CNG  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
#       Kilometers_Driven Fuel_Type Transmission     Mileage   Engine  \
# 0                 72000       CNG       Manual  26.6 km/kg   998 CC
# 1                 41000    Diesel       Manual  19.67 kmpl  1582 CC
# ...

# %%
names=df2['Name'].str.split(' ', expand=True)
names
# Out:
#                   0        1          2          3     4            5  \
# 0            Maruti    Wagon          R        LXI   CNG         None
# 1           Hyundai    Creta        1.6       CRDi    SX       Option
# 2             Honda     Jazz          V       None  None         None
# 3            Maruti   Ertiga        VDI       None  None         None
# 4              Audi       A4        New        2.0   TDI  Multitronic
# ...             ...      ...        ...        ...   ...          ...
# 7248     Volkswagen    Vento     Diesel  Trendline  None         None
# 7249     Volkswagen     Polo         GT        TSI  None         None
# 7250         Nissan    Micra     Diesel         XV  None         None
# 7251     Volkswagen     Polo         GT        TSI  None         None
# 7252  Mercedes-Benz  E-Class  2009-2013          E   220          CDI
#
#                6     7     8     9
# 0           None  None  None  None
# 1           None  None  None  None
# ...

# %%
df2['brand'] = names[0]
df2['model'] = names[1]

# %%
df2['model']
# Out:
# 0         Wagon
# 1         Creta
# 2          Jazz
# 3        Ertiga
# 4            A4
#          ...
# 7248      Vento
# 7249       Polo
# 7250      Micra
# 7251       Polo
# 7252    E-Class
# Name: model, Length: 7198, dtype: object

# %%
df2['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel    3838
# Petrol    3286
# CNG         62
# LPG         12
# Name: count, dtype: int64

# %%
# drop the rows where fuel type is CNG or LPG
# cond1=df2['Fuel_Type']=='Petrol'
# cond1=df2['Fuel_Type']=='Diesel'

# df2=df2[cond1 | cond2]


df2=df2[~df2['Fuel_Type'].isin(['CNG','LPG'])]

# %%
df2['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel    3838
# Petrol    3286
# Name: count, dtype: int64

# %%
df2['Engine']=df2['Engine'].str.replace(' CC','')
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_20528\1816656084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Engine']=df2['Engine'].str.replace(' CC','')

# %%
df2['Engine']
# Out:
# 1       1582
# 2       1199
# 3       1248
# 4       1968
# 6       1461
#         ...
# 7248    1598
# 7249    1197
# 7250    1461
# 7251    1197
# 7252    2148
# Name: Engine, Length: 7124, dtype: object

# %%
df2['Engine']=df2['Engine'].astype(float)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_20528\3037527516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Engine']=df2['Engine'].astype(float)

# %%
df2['Engine']
# Out:
# 1       1582.0
# 2       1199.0
# 3       1248.0
# 4       1968.0
# 6       1461.0
#          ...
# 7248    1598.0
# 7249    1197.0
# 7250    1461.0
# 7251    1197.0
# 7252    2148.0
# Name: Engine, Length: 7124, dtype: float64

# %%
df2['Power']=df2['Power'].str.replace(' bhp','')
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_20528\1199586705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Power']=df2['Power'].str.replace(' bhp','')

# %%
df2['Power']=df2['Power'].str.strip()
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_20528\3223497214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Power']=df2['Power'].str.strip()

# %%
null_value=df2[df2['Power']=='null']
# Out:
#                                          Name  Year  Kilometers_Driven  \
# 76                   Ford Fiesta 1.4 SXi TDCi  2008             111111
# 79                     Hyundai Santro Xing XL  2005              87591
# 89                     Hyundai Santro Xing XO  2007              73745
# 120      Hyundai Santro Xing XL eRLX Euro III  2005             102000
# 143       Hyundai Santro Xing XO eRLX Euro II  2008              80759
# ...                                       ...   ...                ...
# 6891                          Toyota Etios GD  2013              60000
# 6896                     Toyota Etios Liva GD  2013              86000
# 6947                      Toyota Etios Liva G  2012              77800
# 7092  Hyundai Santro Xing XG AT eRLX Euro III  2007              64168
# 7145                      Toyota Etios Liva G  2012              37212
#
#      Fuel_Type Transmission     Mileage  Engine Power  Seats    brand   model
# ...

# %%
df2=df2[df2['Power']!='null']

# %%
df2['Power']=df2['Power'].astype(float)

# %%
df2
# Out:
#                                                    Name  Year  \
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# 6                                Nissan Micra Diesel XV  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
#       Kilometers_Driven Fuel_Type Transmission     Mileage  Engine   Power  \
# 1                 41000    Diesel       Manual  19.67 kmpl  1582.0  126.20
# ...

# %%
df2['Mileage']=df2['Mileage'].str.replace(' kmpl','')

# %%
df2['Mileage']=df2['Mileage'].astype(float)

# %%
df2
# Out:
#                                                    Name  Year  \
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# 6                                Nissan Micra Diesel XV  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
#       Kilometers_Driven Fuel_Type Transmission  Mileage  Engine   Power  \
# 1                 41000    Diesel       Manual    19.67  1582.0  126.20
# 2                 46000    Petrol       Manual    18.20  1199.0   88.70
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7000 entries, 1 to 7252
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7000 non-null   object
#  1   Year               7000 non-null   int64
#  2   Kilometers_Driven  7000 non-null   int64
#  3   Fuel_Type          7000 non-null   object
#  4   Transmission       7000 non-null   object
#  5   Mileage            7000 non-null   float64
#  6   Engine             7000 non-null   float64
#  7   Power              7000 non-null   float64
#  8   Seats              7000 non-null   float64
#  9   brand              7000 non-null   object
#  10  model              7000 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 656.2+ KB

# %%
# Homework (tomorrow)
# one hot encoding for object values
