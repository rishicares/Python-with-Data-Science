# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel(r'seatplanning2079.xlsx')

# %%
data
# Out:
#      Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0             1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1             2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2             3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3             4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4             5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# ..          ...             ...   ...     ...                 ...        ...
# 264         265    803210020265  2080    2102  Grade-11 (General)     URMILA
# 265         266    803210020266  2080    2102  Grade-11 (General)      UTSAB
# 266         267    803210020267  2080    2102  Grade-11 (General)      YALIN
# 267         268    803210020268  2080    2102  Grade-11 (General)     YAMUNA
# 268         269    803210020269  2080    2102  Grade-11 (General)     YUDDHA
#
# ...

# %%
data['Full Name'] = data['First Name'].str.cat(data['Middle Name'], na_rep='').str.cat(data['Last Name'], sep=' ')

# %%
data['Full Name']
# Out:
# 0            AASHUTOSH NEPALI
# 1                  ABHI MAJHI
# 2             ABHISHEK SUBEDI
# 3             ABHISHEK TAMANG
# 4               ABIJAL SUBEDI
#                 ...
# 264        URMILA THAPA MAGAR
# 265           UTSAB ALE MAGAR
# 266               YALIN SUNAM
# 267           YAMUNA SHRESTHA
# 268    YUDDHANARAYAN SHRESTHA
# Name: Full Name, Length: 269, dtype: object

# %%
subjects = data['Registered Subject'].str.split('; ')

# %%
subjects
# Out:
# 0      [ 0051, 1051, 2111, 3331, 0011, 0031]
# 1      [ 0051, 1051, 2111, 4411, 0011, 0031]
# 2      [ 0051, 1031, 3031, 4271, 0011, 0031]
# 3      [ 0051, 1051, 2111, 4411, 0011, 0031]
# 4      [ 0071, 1011, 3011, 4271, 0011, 0031]
#                        ...
# 264    [ 0051, 1031, 2151, 3031, 0011, 0031]
# 265    [ 0071, 1011, 2011, 3011, 0011, 0031]
# 266    [ 0051, 1051, 2111, 4411, 0011, 0031]
# 267    [ 0051, 1151, 2231, 3311, 0011, 0031]
# 268    [ 0051, 1051, 2111, 4411, 0011, 0031]
# Name: Registered Subject, Length: 269, dtype: object

# %%
for i in range(0,6):
    data[f'sub{i+1}'] = data['Registered Subject'].str.split(';').str[i]

# %%
data
# Out:
#      Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0             1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1             2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2             3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3             4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4             5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# ..          ...             ...   ...     ...                 ...        ...
# 264         265    803210020265  2080    2102  Grade-11 (General)     URMILA
# 265         266    803210020266  2080    2102  Grade-11 (General)      UTSAB
# 266         267    803210020267  2080    2102  Grade-11 (General)      YALIN
# 267         268    803210020268  2080    2102  Grade-11 (General)     YAMUNA
# 268         269    803210020269  2080    2102  Grade-11 (General)     YUDDHA
#
# ...

# %%
subcode = pd.read_csv(r'sub.csv')

# %%
subcode
# Out:
#     scode                        subject
# 0       1                         Nepali
# 1       3                        English
# 2       5  Social Studies and Life Skill
# 3       7                    Mathematics
# 4     101                        Physics
# ..    ...                            ...
# 81    353                         French
# 82    355                         Hebrew
# 83    357                         Arabic
# 84    359                       Sanskrit
# 85    361                   Applied Arts
#
# [86 rows x 2 columns]

# %%
for i in range(1, 7):
    data[f'sub{i}'] = data[f'sub{i}'].str[:4]
    data[f'sub{i}'] = data[f'sub{i}'].astype(int)

# %%
data
# Out:
#      Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0             1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1             2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2             3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3             4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4             5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# ..          ...             ...   ...     ...                 ...        ...
# 264         265    803210020265  2080    2102  Grade-11 (General)     URMILA
# 265         266    803210020266  2080    2102  Grade-11 (General)      UTSAB
# 266         267    803210020267  2080    2102  Grade-11 (General)      YALIN
# 267         268    803210020268  2080    2102  Grade-11 (General)     YAMUNA
# 268         269    803210020269  2080    2102  Grade-11 (General)     YUDDHA
#
# ...

# %%
for i in range(1,7):
    data[f'sub{i}'] = data[f'sub{i}'].map(subcode.set_index('scode')['subject'])

# %%
data
# Out:
#      Unnamed: 0 Registration No  Year  School             Program First Name  \
# 0             1    803210020001  2080    2102  Grade-11 (General)  AASHUTOSH
# 1             2    803210020002  2080    2102  Grade-11 (General)       ABHI
# 2             3    803210020003  2080    2102  Grade-11 (General)   ABHISHEK
# 3             4    803210020004  2080    2102  Grade-11 (General)   ABHISHEK
# 4             5    803210020005  2080    2102  Grade-11 (General)     ABIJAL
# ..          ...             ...   ...     ...                 ...        ...
# 264         265    803210020265  2080    2102  Grade-11 (General)     URMILA
# 265         266    803210020266  2080    2102  Grade-11 (General)      UTSAB
# 266         267    803210020267  2080    2102  Grade-11 (General)      YALIN
# 267         268    803210020268  2080    2102  Grade-11 (General)     YAMUNA
# 268         269    803210020269  2080    2102  Grade-11 (General)     YUDDHA
#
# ...
