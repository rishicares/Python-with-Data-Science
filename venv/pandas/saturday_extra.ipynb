# %%
import pandas as pd
import numpy as np

# %%
data={'A':[1,2,3],'B':['3','4']}

data
# Out:
# {'A': [1, 2, 3], 'B': ['3', '4']}

# %%
list_x = pd.Series(data)

# %%
dat = pd.DataFrame(list_x)
dat
# Out:
#            0
# A  [1, 2, 3]
# B     [3, 4]

# %%
df = pd.read_csv(r'employee_records.csv')

# %%
df.head()
# Out:
#                             Employee ID    Employee Name  \
# 0  f086e110-447e-47bb-8216-f43333b83c99    Anna Alvarado
# 1  d6f4d4f0-ed64-412b-8839-6d58f1e2d677   Peter Williams
# 2  10855e43-7e2e-4336-b399-5bcb75d9ebb2  Crystal Mcguire
# 3  1356a938-2c8c-419b-9c3f-28d2a742b668    Daniel Miller
# 4  afc415b8-e9e6-4f3a-9645-c8f7906c8022        James Kim
#
#                                              Address  \
# 0  1812 Christopher Ways Apt. 060\nPort Cody, PW ...
# 1              265 David Light\nAngelaport, AZ 34012
# 2  07950 Scott Course Apt. 268\nWest Stephanie, C...
# 3  6660 Karen Hills Suite 025\nNicholasshire, GU ...
# 4  5544 Morrison Villages\nEast Staceyborough, MA...
#
#                           Post  Monthly Salary  Age Marital Status  Gender
# 0          Geologist, wellsite         9009.93   43        Married    Male
# 1        Aeronautical engineer         7048.79   38        Married    Male
# ...

# %%
df.tail()
# Out:
#                               Employee ID   Employee Name  \
# 995  d2993076-1a8d-4a44-88d1-6710aa07d674    Martin Davis
# 996  4250e49d-4ad3-4fa4-a7d2-c612862eb473   Malik Johnson
# 997  5111e828-b815-4183-b805-e3dc58cc188b  Annette Rangel
# 998  38fe4302-0a73-4574-8af5-29cd66f31768      John Baker
# 999  c162ffea-098b-466a-8ef1-b14f81dfa0aa     Dawn Bailey
#
#                                                Address  \
# 995  0057 Timothy Port Suite 030\nThompsonchester, ...
# 996            815 Mccarthy Cliff\nSawyerton, WY 87847
# 997  4335 Austin Mews Apt. 100\nSouth Michael, NY 6...
# 998            97644 Maureen Mews\nPort John, MH 69325
# 999  21025 Kelly View Apt. 041\nWigginsmouth, WA 11468
#
#                                  Post  Monthly Salary  Age Marital Status  \
# 995                     Ranger/warden         7844.79   41        Married
# 996      Engineer, civil (consulting)         4329.57   50        Married
# ...

# %%
df.columns
# Out:
# Index(['Employee ID', 'Employee Name', 'Address', 'Post', 'Monthly Salary',
#        'Age', 'Marital Status', 'Gender'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Employee ID     1000 non-null   object
#  1   Employee Name   1000 non-null   object
#  2   Address         1000 non-null   object
#  3   Post            1000 non-null   object
#  4   Monthly Salary  1000 non-null   float64
#  5   Age             1000 non-null   int64
#  6   Marital Status  1000 non-null   object
#  7   Gender          1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        Monthly Salary          Age
# count     1000.000000  1000.000000
# mean      7457.792700    37.614000
# std       2552.163376     7.498882
# min       3014.710000    25.000000
# 25%       5310.072500    31.000000
# 50%       7528.080000    38.000000
# 75%       9599.147500    44.000000
# max      11998.490000    50.000000

# %% [markdown]
# <h1>Accessing Data</h1>

# %%
df['Employee Name']
# Out:
# 0        Anna Alvarado
# 1       Peter Williams
# 2      Crystal Mcguire
# 3        Daniel Miller
# 4            James Kim
#             ...
# 995       Martin Davis
# 996      Malik Johnson
# 997     Annette Rangel
# 998         John Baker
# 999        Dawn Bailey
# Name: Employee Name, Length: 1000, dtype: object

# %%
df[['Employee Name','Address']]
# Out:
#        Employee Name                                            Address
# 0      Anna Alvarado  1812 Christopher Ways Apt. 060\nPort Cody, PW ...
# 1     Peter Williams              265 David Light\nAngelaport, AZ 34012
# 2    Crystal Mcguire  07950 Scott Course Apt. 268\nWest Stephanie, C...
# 3      Daniel Miller  6660 Karen Hills Suite 025\nNicholasshire, GU ...
# 4          James Kim  5544 Morrison Villages\nEast Staceyborough, MA...
# ..               ...                                                ...
# 995     Martin Davis  0057 Timothy Port Suite 030\nThompsonchester, ...
# 996    Malik Johnson            815 Mccarthy Cliff\nSawyerton, WY 87847
# 997   Annette Rangel  4335 Austin Mews Apt. 100\nSouth Michael, NY 6...
# 998       John Baker            97644 Maureen Mews\nPort John, MH 69325
# 999      Dawn Bailey  21025 Kelly View Apt. 041\nWigginsmouth, WA 11468
#
# [1000 rows x 2 columns]

# %%
type(df[['Employee Name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - setindex()
# - resetindex()

# %%
dat = {
    'Name':['Tom', 'nick', 'krish', 'jack'],
    'Age':[20, 21, 19, 18]
}
df=pd.DataFrame(dat)
df
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
df.set_index('Name', inplace=True)
df
# Out:
#        Age
# Name
# Tom     20
# nick    21
# krish   19
# jack    18

# %%
demo = pd.read_csv(r'demo.csv')
demo
# Out:
#     sid        name   address
# 0    101      SUJAN        NaN
# 1    102  RISHIKESH        NaN
# 2    103     PRABAL        NaN
# 3    104     PRAKRTI       NaN
# 4    105        ANJU       NaN
# 5    106    MANISHA        NaN
# 6    107       PRENA       NaN
# 7    108    DEVANSHA       NaN
# 8    109     SABINA        NaN
# 9    110       BIBKE       NaN
# 10   111      MANOZ        NaN
# 11   112        AGFF       NaN
# 12   113       SGFEF       NaN
# 13   114        AGWG       NaN
# 14   115         SGG       NaN
# 15   116        SGRG       NaN
# 16   117        RGRG       NaN

# %%
demo.set_index('sid ',inplace=True)

# %%
demo
# Out:
#            name   address
# sid
# 101       SUJAN        NaN
# 102   RISHIKESH        NaN
# 103      PRABAL        NaN
# 104      PRAKRTI       NaN
# 105         ANJU       NaN
# 106     MANISHA        NaN
# 107        PRENA       NaN
# 108     DEVANSHA       NaN
# 109      SABINA        NaN
# 110        BIBKE       NaN
# 111       MANOZ        NaN
# 112         AGFF       NaN
# 113        SGFEF       NaN
# 114         AGWG       NaN
# 115          SGG       NaN
# 116         SGRG       NaN
# 117         RGRG       NaN

# %%
demo.reset_index('sid ', inplace=True)

# %%
demo
# Out:
#     sid        name   address
# 0    101      SUJAN        NaN
# 1    102  RISHIKESH        NaN
# 2    103     PRABAL        NaN
# 3    104     PRAKRTI       NaN
# 4    105        ANJU       NaN
# 5    106    MANISHA        NaN
# 6    107       PRENA       NaN
# 7    108    DEVANSHA       NaN
# 8    109     SABINA        NaN
# 9    110       BIBKE       NaN
# 10   111      MANOZ        NaN
# 11   112        AGFF       NaN
# 12   113       SGFEF       NaN
# 13   114        AGWG       NaN
# 14   115         SGG       NaN
# 15   116        SGRG       NaN
# 16   117        RGRG       NaN

# %%
demo_x=demo[['sid ','name ']]

# %%
demo_x
# Out:
#     sid        name
# 0    101      SUJAN
# 1    102  RISHIKESH
# 2    103     PRABAL
# 3    104     PRAKRTI
# 4    105        ANJU
# 5    106    MANISHA
# 6    107       PRENA
# 7    108    DEVANSHA
# 8    109     SABINA
# 9    110       BIBKE
# 10   111      MANOZ
# 11   112        AGFF
# 12   113       SGFEF
# 13   114        AGWG
# 14   115         SGG
# 15   116        SGRG
# 16   117        RGRG

# %%
demo_x.head()
# Out:
#    sid        name
# 0   101      SUJAN
# 1   102  RISHIKESH
# 2   103     PRABAL
# 3   104     PRAKRTI
# 4   105        ANJU

# %% [markdown]
# loc and iloc
# i - Index
# l - label

# %%
demo.iloc[0]
demo
# Out:
#     sid        name   address
# 0    101      SUJAN        NaN
# 1    102  RISHIKESH        NaN
# 2    103     PRABAL        NaN
# 3    104     PRAKRTI       NaN
# 4    105        ANJU       NaN
# 5    106    MANISHA        NaN
# 6    107       PRENA       NaN
# 7    108    DEVANSHA       NaN
# 8    109     SABINA        NaN
# 9    110       BIBKE       NaN
# 10   111      MANOZ        NaN
# 11   112        AGFF       NaN
# 12   113       SGFEF       NaN
# 13   114        AGWG       NaN
# 14   115         SGG       NaN
# 15   116        SGRG       NaN
# 16   117        RGRG       NaN

# %%
demo.iloc[0:5]
# Out:
#    sid        name   address
# 0   101      SUJAN        NaN
# 1   102  RISHIKESH        NaN
# 2   103     PRABAL        NaN
# 3   104     PRAKRTI       NaN
# 4   105        ANJU       NaN

# %%
demo.iloc[0]
# Out:
# sid            101
# name        SUJAN
# address        NaN
# Name: 0, dtype: object

# %%
demo.iloc[[1,3,6]]
# Out:
#    sid        name   address
# 1   102  RISHIKESH        NaN
# 3   104     PRAKRTI       NaN
# 6   107       PRENA       NaN

# %%
demo.iloc[1,1]
# Out:
# 'RISHIKESH '

# %%
ps = pd.read_csv(r'playstore.xls')
ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - first five rows of data set
# - last five rows of dataset
# - shape of dataset
# - describe dataset
# - info
# - 3 shape

# %%
ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
ps.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
ps.shape
# Out:
# (10841, 13)

# %%
ps.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# fetch records from 1,5,7,9,11
ps.iloc[[1,5,7,9,11]]
# Out:
#                                         App        Category  Rating Reviews  \
# 1                       Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                Paper flowers instructions  ART_AND_DESIGN     4.4     167
# 7                          Infinite Painter  ART_AND_DESIGN     4.1   36815
# 9             Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7     121
# 11  Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4    8788
#
#     Size    Installs  Type Price Content Rating                     Genres  \
# 1    14M    500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 5   5.6M     50,000+  Free     0       Everyone               Art & Design
# 7    29M  1,000,000+  Free     0       Everyone               Art & Design
# 9   3.1M     10,000+  Free     0       Everyone    Art & Design;Creativity
# 11   12M  1,000,000+  Free     0       Everyone               Art & Design
#
#         Last Updated Current Ver   Android Ver
# ...

# %%
ps.iloc[1:5,1:5]
# Out:
#          Category  Rating Reviews  Size
# 1  ART_AND_DESIGN     3.9     967   14M
# 2  ART_AND_DESIGN     4.7   87510  8.7M
# 3  ART_AND_DESIGN     4.5  215644   25M
# 4  ART_AND_DESIGN     4.3     967  2.8M

# %% [markdown]
# # filtering records in DataFrame

# %%
df['Monthly Salary']>7000
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997     True
# 998    False
# 999    False
# Name: Monthly Salary, Length: 1000, dtype: bool

# %%
df[df['Monthly Salary']>7000]
# Out:
#                               Employee ID     Employee Name  \
# 0    f086e110-447e-47bb-8216-f43333b83c99     Anna Alvarado
# 1    d6f4d4f0-ed64-412b-8839-6d58f1e2d677    Peter Williams
# 2    10855e43-7e2e-4336-b399-5bcb75d9ebb2   Crystal Mcguire
# 4    afc415b8-e9e6-4f3a-9645-c8f7906c8022         James Kim
# 6    d426c843-2c2f-4ed5-b72b-bcf8aeaa6868     Kyle Crawford
# ..                                    ...               ...
# 991  293e2e7a-e430-499f-ba0e-9db7d00c6d49      Angel Bailey
# 992  4063bf6b-d955-4863-9e05-122b2a9b4bf3   Steven Campbell
# 994  937c36ac-97b4-40ad-b73f-0069ad539447  Benjamin Alvarez
# 995  d2993076-1a8d-4a44-88d1-6710aa07d674      Martin Davis
# 997  5111e828-b815-4183-b805-e3dc58cc188b    Annette Rangel
#
#                                                Address  \
# 0    1812 Christopher Ways Apt. 060\nPort Cody, PW ...
# 1                265 David Light\nAngelaport, AZ 34012
# 2    07950 Scott Course Apt. 268\nWest Stephanie, C...
# ...

# %%
mask = df['Monthly Salary']>7000
df[mask]
# Out:
#                               Employee ID     Employee Name  \
# 0    f086e110-447e-47bb-8216-f43333b83c99     Anna Alvarado
# 1    d6f4d4f0-ed64-412b-8839-6d58f1e2d677    Peter Williams
# 2    10855e43-7e2e-4336-b399-5bcb75d9ebb2   Crystal Mcguire
# 4    afc415b8-e9e6-4f3a-9645-c8f7906c8022         James Kim
# 6    d426c843-2c2f-4ed5-b72b-bcf8aeaa6868     Kyle Crawford
# ..                                    ...               ...
# 991  293e2e7a-e430-499f-ba0e-9db7d00c6d49      Angel Bailey
# 992  4063bf6b-d955-4863-9e05-122b2a9b4bf3   Steven Campbell
# 994  937c36ac-97b4-40ad-b73f-0069ad539447  Benjamin Alvarez
# 995  d2993076-1a8d-4a44-88d1-6710aa07d674      Martin Davis
# 997  5111e828-b815-4183-b805-e3dc58cc188b    Annette Rangel
#
#                                                Address  \
# 0    1812 Christopher Ways Apt. 060\nPort Cody, PW ...
# 1                265 David Light\nAngelaport, AZ 34012
# 2    07950 Scott Course Apt. 268\nWest Stephanie, C...
# ...

# %%
mask1 = df['Monthly Salary']>7000
mask2 = df['Gender']=='Female'
mask3 = df['Age']>25
df[mask1 & mask2 & mask3]
# Out:
#                               Employee ID    Employee Name  \
# 2    10855e43-7e2e-4336-b399-5bcb75d9ebb2  Crystal Mcguire
# 4    afc415b8-e9e6-4f3a-9645-c8f7906c8022        James Kim
# 7    c40f0471-a20b-4099-814f-890c96c45b60     Thomas Moore
# 21   1afe5995-1351-404c-a792-4feae22eff03    Robert Lozano
# 22   90af2324-3a02-4873-866d-ca367904fc68     Jamie Taylor
# ..                                    ...              ...
# 981  c573a0aa-b359-4c35-be29-c2234dd78534      Debra Smith
# 983  b10278e5-dc5a-426a-b8df-1d07556890c9       Eric Smith
# 992  4063bf6b-d955-4863-9e05-122b2a9b4bf3  Steven Campbell
# 995  d2993076-1a8d-4a44-88d1-6710aa07d674     Martin Davis
# 997  5111e828-b815-4183-b805-e3dc58cc188b   Annette Rangel
#
#                                                Address  \
# 2    07950 Scott Course Apt. 268\nWest Stephanie, C...
# 4    5544 Morrison Villages\nEast Staceyborough, MA...
# 7          6914 Sara Mews\nSouth Jeffreyberg, FL 03937
# ...

# %%
# filter female with age more than 25 and salary 7000 using loc
df.loc[mask1 & mask2 & mask3]
# Out:
#                               Employee ID    Employee Name  \
# 2    10855e43-7e2e-4336-b399-5bcb75d9ebb2  Crystal Mcguire
# 4    afc415b8-e9e6-4f3a-9645-c8f7906c8022        James Kim
# 7    c40f0471-a20b-4099-814f-890c96c45b60     Thomas Moore
# 21   1afe5995-1351-404c-a792-4feae22eff03    Robert Lozano
# 22   90af2324-3a02-4873-866d-ca367904fc68     Jamie Taylor
# ..                                    ...              ...
# 981  c573a0aa-b359-4c35-be29-c2234dd78534      Debra Smith
# 983  b10278e5-dc5a-426a-b8df-1d07556890c9       Eric Smith
# 992  4063bf6b-d955-4863-9e05-122b2a9b4bf3  Steven Campbell
# 995  d2993076-1a8d-4a44-88d1-6710aa07d674     Martin Davis
# 997  5111e828-b815-4183-b805-e3dc58cc188b   Annette Rangel
#
#                                                Address  \
# 2    07950 Scott Course Apt. 268\nWest Stephanie, C...
# 4    5544 Morrison Villages\nEast Staceyborough, MA...
# 7          6914 Sara Mews\nSouth Jeffreyberg, FL 03937
# ...

# %%
#nunique()
ps['Category'].nunique()
# Out:
# 34

# %%
ps['Category'].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
ps['Genres'].value_counts()
# Out:
# Genres
# Tools                     842
# Entertainment             623
# Education                 549
# Medical                   463
# Business                  460
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: count, Length: 120, dtype: int64

# %%
ps['Genres'].nunique()
# Out:
# 120

# %% [markdown]
# # Questions
# 1. top 10 most downloaded apps
# 2. top 10 least downloaded apps
# 3. when the max no. of apps were downloaded
# 5. create a list of apps, getting rating more than 4

# %%
ps = pd.read_csv(r'playstore.xls')
ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
top_10_apps = ps.sort_values('Installs', ascending=False).head(10)
top_10_apps[['App', 'Installs']]
# Out:
#                                                App      Installs
# 10472      Life Made WI-Fi Touchscreen Photo Frame          Free
# 420    UC Browser - Fast Download Private & Secure  500,000,000+
# 474                    LINE: Free Calls & Messages  500,000,000+
# 3767                  Flipboard: News For Our Time  500,000,000+
# 3574                                   Cloud Print  500,000,000+
# 3326                  Gboard - the Google Keyboard  500,000,000+
# 431                                Viber Messenger  500,000,000+
# 4222                 imo free video calls and chat  500,000,000+
# 3235                              Google Translate  500,000,000+
# 1842                              Candy Crush Saga  500,000,000+

# %%
bottom_10_apps = ps.sort_values('Installs').head(10)
bottom_10_apps[['App','Installs']]
# Out:
#                             App Installs
# 9148  Command & Conquer: Rivals        0
# 5486     AP Series Solution Pro       0+
# 8614          Sweden Newspapers       0+
# 9337   EG | Explore Folegandros       0+
# 9719               EP Cook Book       0+
# 9917                Eu Sou Rico       0+
# 8871     Test Application DT 02       0+
# 9905                Eu sou Rico       0+
# 6692              cronometra-br       0+
# 5307    Ak Parti Yardım Toplama       0+

# %%
ps['Last Updated'].value_counts().head(1)
# Out:
# Last Updated
# August 3, 2018    326
# Name: count, dtype: int64

# %%
mask1 = ps['Rating']>4
mt4 = ps[mask1]
mt4['App'].tolist()
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook',
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  'Sketch - Draw & Paint',
#  'Pixel Draw - Number Art Coloring Book',
#  'Paper flowers instructions',
#  'Infinite Painter',
#  'Garden Coloring Book',
#  'Kids Paint Free - Drawing Fun',
#  'Text on Photo - Fonteee',
#  'Name Art Photo Editor - Focus n Filters',
#  'Tattoo Name On My Photo Editor',
#  'Mandala Coloring Book',
#  '3D Color Pixel by Number - Sandbox Art Coloring',
#  'Photo Designer - Write your name with shapes',
#  '350 Diy Room Decor Ideas',
#  'FlipaClip - Cartoon animation',
#  'ibis Paint X',
#  "Boys Photo Editor - Six Pack & Men's Suit",
#  'Superheroes Wallpapers | 4K Backgrounds',
#  'HD Mickey Minnie Wallpapers',
#  'Harley Quinn wallpapers HD',
#  'Colorfit - Drawing & Coloring',
#  'Animated Photo Editor',
#  'Easy Realistic Drawing Tutorial',
#  'Pink Silver Bow Keyboard Theme',
#  'Art Drawing Ideas',
#  'Anime Manga Coloring Book',
# ...
