# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'pandas/used_cars_data.csv')

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data['Engine']=data['Engine'].str.replace('CC','')

data['Engine'] = data['Engine'].astype(float)

# %%
data['Engine'].dtype
# Out:
# dtype('float64')

# %%
data['Power']=data['Power'].str.replace('bhp', '')
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data['Power'].isnull().sum()
# Out:
# 46

# %%
data['Power']=pd.to_numeric(data['Power'], errors='coerce')
data['Power'].isna().sum()
# Out:
# 175

# %%
x=data['Power'].mean()

# %%
data['Power']=data['Power'].fillna(x)

# %%
data['Power'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                   0
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
data['Seats']= data['Seats'].fillna(method='bfill')
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_21064\3231328054.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Seats']= data['Seats'].fillna(method='bfill')

# %%
data.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                   0
# Seats                   0
# New_Price            6247
# Price                1234
# dtype: int64

# %%
hotel_data = pd.read_excel('hotels_data.xlsx')

# %%
hotel_data
# Out:
#                                                     area  \
# 0                                      Hardasji Ki Magri
# 1                                          Near Nai Gaon
# 2                                  Near Bagore Ki Haveli
# 3                                                  Dabok
# 4                                           East Udaipur
# ...                                                  ...
# 20073                            Thonichal, Mananthavady
# 20074                                                NaN
# 20075                       Central Mysore,Nazarbad Road
# 20076                                            Wayanad
# 20077  Opp. APSEB Sub Station,Behind Bezwada Home Foo...
#
#                                city country           crawl_date  \
# 0                           Udaipur   India  2016-06-21 00:00:00
# 1                           Udaipur   India  2016-06-21 00:00:00
# 2                           Udaipur   India  2016-06-21 00:00:00
# ...

# %%
hotel_data['city'].value_counts()
# Out:
# city
# NewDelhiAndNCR    944
# Goa               836
# Bangalore         600
# Mumbai            577
# Jaipur            566
#                  ...
# Kapurthala          1
# Vizianagram         1
# Sonipat             1
# Balangir            1
# Haldia              1
# Name: count, Length: 762, dtype: int64

# %%
# scatter plot city and star
# plot if hotels > 50 in city

# cars data (linear regression) home

# %%
# Supervised Machine Learning
# a) Linear Regression
# b) Logistic Regression

# Unsupervised Machine Learning
# a) KMeans

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
tips=sns.load_dataset('tips')

# %%
cols=['sex', 'smoker', 'day','time']

# %%
for col in cols:
    tips[col]=LabelEncoder().fit_transform(tips[col])

# %%
cols_to_scale = ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']
tips[cols_to_scale]=MinMaxScaler().fit_transform(tips[cols_to_scale])

# %%
tips
# Out:
#      total_bill       tip  sex  smoker       day  time  size
# 0      0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1      0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2      0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3      0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4      0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# ..          ...       ...  ...     ...       ...   ...   ...
# 239    0.543779  0.546667  1.0     0.0  0.333333   0.0   0.4
# 240    0.505027  0.111111  0.0     1.0  0.333333   0.0   0.2
# 241    0.410557  0.111111  1.0     1.0  0.333333   0.0   0.2
# 242    0.308965  0.083333  1.0     0.0  0.333333   0.0   0.2
# 243    0.329074  0.222222  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)
# Out:
# c:\Users\rishi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rishi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rishi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
x=tips.drop(['tip'], axis=1)
y=tips['tip']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Model Train
# r2 score
# mse

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# prediction
# saving (pickling) joblib
# r2

# %%
tips.to_csv('tips_data_ready_to_use.csv')

# %%
# cars data
# data cleaning ipynb
# encode
# scaling
# train_test_split
# model_train
# used_cars (mileage) (price, newprice)
