# %%
#feature scaling
# minmax scaler
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
tips = sns.load_dataset('tips')

# %%
tips
tips_copy = tips.copy()

# %%
sns.scatterplot(x='tip',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
#scatter plot of tips and total bill before scaling
cols_to_scale =['tip','total_bill']
tips[cols_to_scale] = MinMaxScaler().fit_transform(tips[cols_to_scale])

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean       0.350145
# std        0.186477
# min        0.000000
# 25%        0.215281
# 50%        0.308442
# 75%        0.441087
# max        1.000000
# Name: total_bill, dtype: float64

# %%
sns.scatterplot(x='tip',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
#label encoding
# manual,automatic
tips
# Out:
#      total_bill       tip     sex smoker   day    time  size
# 0      0.291579  0.001111  Female     No   Sun  Dinner     2
# 1      0.152283  0.073333    Male     No   Sun  Dinner     3
# 2      0.375786  0.277778    Male     No   Sun  Dinner     3
# 3      0.431713  0.256667    Male     No   Sun  Dinner     2
# 4      0.450775  0.290000  Female     No   Sun  Dinner     4
# ..          ...       ...     ...    ...   ...     ...   ...
# 239    0.543779  0.546667    Male     No   Sat  Dinner     3
# 240    0.505027  0.111111  Female    Yes   Sat  Dinner     2
# 241    0.410557  0.111111    Male    Yes   Sat  Dinner     2
# 242    0.308965  0.083333    Male     No   Sat  Dinner     2
# 243    0.329074  0.222222  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
col_to_encode = ['sex','smoker','day','time']
for x in col_to_encode:
    # tips[x] = LabelEncoder.fit_transform(tips[x])
    # tips[col_to_encode] = LabelEncoder().fit_transform(tips[col_to_encode])
    # tips[ ['sex','smoker','day','time']] = LabelEncoder().fit_transform(tips[ ['sex','smoker','day','time']])
    tips['sex']=LabelEncoder().fit_transform(tips['sex'])

# %%
tips
# Out:
#      total_bill       tip  sex smoker   day    time  size
# 0      0.291579  0.001111    0     No   Sun  Dinner     2
# 1      0.152283  0.073333    1     No   Sun  Dinner     3
# 2      0.375786  0.277778    1     No   Sun  Dinner     3
# 3      0.431713  0.256667    1     No   Sun  Dinner     2
# 4      0.450775  0.290000    0     No   Sun  Dinner     4
# ..          ...       ...  ...    ...   ...     ...   ...
# 239    0.543779  0.546667    1     No   Sat  Dinner     3
# 240    0.505027  0.111111    0    Yes   Sat  Dinner     2
# 241    0.410557  0.111111    1    Yes   Sat  Dinner     2
# 242    0.308965  0.083333    1     No   Sat  Dinner     2
# 243    0.329074  0.222222    0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['smoker'] = LabelEncoder().fit_transform(tips['smoker'])

# %%
tips
# Out:
#      total_bill       tip  sex  smoker   day    time  size
# 0      0.291579  0.001111    0       0   Sun  Dinner     2
# 1      0.152283  0.073333    1       0   Sun  Dinner     3
# 2      0.375786  0.277778    1       0   Sun  Dinner     3
# 3      0.431713  0.256667    1       0   Sun  Dinner     2
# 4      0.450775  0.290000    0       0   Sun  Dinner     4
# ..          ...       ...  ...     ...   ...     ...   ...
# 239    0.543779  0.546667    1       0   Sat  Dinner     3
# 240    0.505027  0.111111    0       1   Sat  Dinner     2
# 241    0.410557  0.111111    1       1   Sat  Dinner     2
# 242    0.308965  0.083333    1       0   Sat  Dinner     2
# 243    0.329074  0.222222    0       0  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['day'] = LabelEncoder().fit_transform(tips['day'])

# %%
tips['time'] = LabelEncoder().fit_transform(tips['time'])

# %%
col_to_scale =  ['sex','smoker','day','time']

# %%
tips[col_to_scale] = MinMaxScaler().fit_transform(tips[col_to_scale])

# %% [raw]
# #machine learning
# train and test
# 80% train
# 20% test
# #scaling
# before train test split ,do scaling and then split()
# for scaling we have to get clean data

# %%
df = pd.read_csv(r'new_cars_data_cleaned.csv')

# %%
df
# Out:
#       Unnamed: 0    location  year    run    fuel      trans   owner  mileage  \
# 0              0      Mumbai  2010  72000     CNG     Manual   First    26.60
# 1              1        Pune  2015  41000  Diesel     Manual   First    19.67
# 2              2     Chennai  2011  46000  Petrol     Manual   First    18.20
# 3              3     Chennai  2012  87000  Diesel     Manual   First    20.77
# 4              4  Coimbatore  2013  40670  Diesel  Automatic  Second    15.20
# ...          ...         ...   ...    ...     ...        ...     ...      ...
# 7248        7248   Hyderabad  2011  89411  Diesel     Manual   First    20.54
# 7249        7249      Mumbai  2015  59000  Petrol  Automatic   First    17.21
# 7250        7250     Kolkata  2012  28000  Diesel     Manual   First    23.08
# 7251        7251        Pune  2013  52262  Petrol  Automatic   Third    17.20
# 7252        7252       Kochi  2014  72443  Diesel  Automatic   First    10.00
#
# ...

# %%
#data CLeaning
df.isna().sum()
# Out:
# Unnamed: 0     0
# location       0
# year           0
# run            0
# fuel           0
# trans          0
# owner          0
# mileage        0
# engine         0
# power         46
# seats         53
# brand          0
# model          0
# dtype: int64

# %%
drop_row = df.copy()
drop_row2 = df.copy()
drop_col = df.copy()

# %%
#dropping row
drop_row2.dropna()
# Out:
#       Unnamed: 0    location  year    run    fuel      trans   owner  mileage  \
# 0              0      Mumbai  2010  72000     CNG     Manual   First    26.60
# 1              1        Pune  2015  41000  Diesel     Manual   First    19.67
# 2              2     Chennai  2011  46000  Petrol     Manual   First    18.20
# 3              3     Chennai  2012  87000  Diesel     Manual   First    20.77
# 4              4  Coimbatore  2013  40670  Diesel  Automatic  Second    15.20
# ...          ...         ...   ...    ...     ...        ...     ...      ...
# 7248        7248   Hyderabad  2011  89411  Diesel     Manual   First    20.54
# 7249        7249      Mumbai  2015  59000  Petrol  Automatic   First    17.21
# 7250        7250     Kolkata  2012  28000  Diesel     Manual   First    23.08
# 7251        7251        Pune  2013  52262  Petrol  Automatic   Third    17.20
# 7252        7252       Kochi  2014  72443  Diesel  Automatic   First    10.00
#
# ...

# %%
#mean()
#fillna()
df.isna().sum()
# Out:
# Unnamed: 0     0
# location       0
# year           0
# run            0
# fuel           0
# trans          0
# owner          0
# mileage        0
# engine         0
# power         46
# seats         53
# brand          0
# model          0
# dtype: int64

# %%
df1 = pd.read_csv(r'used_cars_data.csv')

# %%
df1['Power'] = df1['Power'].str.replace(' ' ,'')

# %%
df1['Mileage'] = df1['Mileage'].str.replace('kmpl' ,'')

# %%
df1['Mileage'] = df1['Mileage'].astype('float')

# %%
df1['Power'] = df1['Power'].fillna(df1['Power'].notna().mean())

# %%
df1['Power'].isna().info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7253 entries, 0 to 7252
# Series name: Power
# Non-Null Count  Dtype
# --------------  -----
# 7253 non-null   bool
# dtypes: bool(1)
# memory usage: 7.2 KB

# %%
df1['Power'] = pd.to_numeric(df1['Power'], errors='coerce')

# %%
df1['Power'] = df1['Power'].fillna(df1['Power'].mean())

# %%
df1['Power'] = df1['Power'].astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   object
#  10  Power              7253 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 793.4+ KB

# %%
#encode used_cars_data
# scale used_cars_Data
#price fill price hamle aafai search garera rakhni 
# new price search garni

# %%
df1['Power'].isna().sum()
# Out:
# 0

# %%
x = df['mileage'].mean()

# %%
fillna()
''' mean
forward fill ffill
backward fill bfill '''
